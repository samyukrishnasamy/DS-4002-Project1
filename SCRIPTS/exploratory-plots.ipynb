# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("SMSSpamCollection.csv")

# %%
print(df.head())
# Out:
#   Label                                        SMS Message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(6,4))
sns.barplot(x=missing_counts.index, y=missing_counts.values, palette="Set2")
plt.title("Count of Missing Values per Column")
plt.ylabel("Number of Missing Values")
plt.xlabel("Columns")
plt.show()
# Out:
# /var/folders/28/snq1pkyd68jdmfy73dssxll40000gn/T/ipykernel_31579/1012990523.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=missing_counts.index, y=missing_counts.values, palette="Set2")

# %%
# --- Plot 1: Class Distribution ---
plt.figure(figsize=(6,4))
sns.countplot(x="Label", data=df, palette="Set1")
plt.title("Class Distribution of SMS Messages")
plt.xlabel("Message Type")
plt.ylabel("Count")
plt.show()
# Out:
# /var/folders/28/snq1pkyd68jdmfy73dssxll40000gn/T/ipykernel_31579/1610086726.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Label", data=df, palette="Set1")

# %%
# --- Plot 2: Message Length Distribution ---
# Add a new column for message length
df["msg_length"] = df["SMS Message"].apply(len)

plt.figure(figsize=(8,5))
sns.histplot(data=df, x="msg_length", hue="Label", bins=50, kde=True, palette="Set1")
plt.title("Distribution of Message Lengths by Class")
plt.xlabel("Message Length (characters)")
plt.ylabel("Frequency")
plt.xlim(0, 300)
plt.show()
